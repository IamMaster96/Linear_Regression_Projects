# %%
import wbgapi as wb
import pandas as pd
from matplotlib import pyplot as plt

# %%
wb.db=2

# %%
co2_emission_KT=wb. data. DataFrame (['EN.ATM.CO2E.KT' ],['AFG','WLD' ],range (1990, 2015),numericTimeKeys=True,)

# %%
years=range(1990,2015)
co2_emission_KT_np=co2_emission_KT.to_numpy()

# %%
plt.plot(years,x[1],'o-')
